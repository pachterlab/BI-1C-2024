# %% [markdown]
# <a href="https://colab.research.google.com/github/pachterlab/BI-1C-2024/blob/main/Square_number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model

# Function to convert binary number to decimal
def binary_to_decimal(binary_vector):
    return np.dot(binary_vector, 2**np.arange(binary_vector.size)[::-1])

# Function to convert decimal to binary number of a fixed size
def decimal_to_binary(n, vector_length=10):
    binary_vector = np.array(list(np.binary_repr(n).zfill(vector_length))).astype(np.float32)
    return binary_vector

# Generate a training dataset
def generate_data(num_samples=2000, input_length=5, output_length=10):
    X = np.random.randint(0, 2, (num_samples, input_length)).astype(np.float32)
    Y = np.array([decimal_to_binary(int(binary_to_decimal(x))**2, output_length) for x in X])
    return X, Y

# Create the model
def create_model(input_dim, output_dim):
    model = Sequential([
        Dense(128, input_dim=input_dim, activation='sigmoid'),
        Dense(64, activation='sigmoid'),
        Dense(32, activation='sigmoid'),
        Dense(output_dim, activation='sigmoid')
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Main function
def main():
    input_length = 5
    output_length = 10
    X, Y = generate_data(1000, input_length, output_length)

    model = create_model(input_length, output_length)
    model.summary()

    # Plot and save a figure contraining a diagram of the model
    plot_model(model, to_file='model.png', show_shapes=True, show_layer_names=True)
    print("A diagram of the model saved in the file 'model.png'")

    # Train the model
    model.fit(X, Y, epochs=100, batch_size=32, verbose=1)

    # Test the model with a random input
    test_input = np.random.randint(0, 2, (1, input_length)).astype(np.float32)
    test_output = model.predict(test_input)
    input_decimal = int(binary_to_decimal(test_input[0]))
    output_decimal = int(binary_to_decimal((test_output > 0.5).astype(int)[0]))
    print("Input Binary Vector (5 bits):", test_input[0])
    print("Input in Decimal:", input_decimal)
    print("Predicted Squared Binary Vector (10 bits):", (test_output > 0.5).astype(int)[0])
    print("Predicted Output in Decimal:", output_decimal)

if __name__ == "__main__":
    main()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_28 (Dense)            (None, 128)               768
#
#  dense_29 (Dense)            (None, 64)                8256
#
#  dense_30 (Dense)            (None, 32)                2080
#
#  dense_31 (Dense)            (None, 10)                330
#
# =================================================================
# Total params: 11434 (44.66 KB)
# Trainable params: 11434 (44.66 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# A diagram of the model saved in the file 'model.png'
# Epoch 1/100
# 32/32 [==============================] - 1s 4ms/step - loss: 0.6394 - accuracy: 0.2310
# Epoch 2/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5867 - accuracy: 0.0280
# Epoch 3/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5788 - accuracy: 0.0280
# Epoch 4/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5760 - accuracy: 0.0280
# Epoch 5/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5741 - accuracy: 0.0280
# Epoch 6/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5729 - accuracy: 0.0280
# Epoch 7/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5719 - accuracy: 0.0280
# Epoch 8/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5700 - accuracy: 0.0280
# Epoch 9/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5672 - accuracy: 0.0280
# Epoch 10/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5623 - accuracy: 0.0290
# Epoch 11/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5535 - accuracy: 0.0360
# Epoch 12/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5380 - accuracy: 0.0790
# Epoch 13/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.5129 - accuracy: 0.1130
# Epoch 14/100
# 32/32 [==============================] - 0s 4ms/step - loss: 0.4833 - accuracy: 0.1690
# Epoch 15/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4559 - accuracy: 0.2000
# Epoch 16/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4346 - accuracy: 0.2030
# Epoch 17/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.4173 - accuracy: 0.1590
# Epoch 18/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4022 - accuracy: 0.1850
# Epoch 19/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.2050
# Epoch 20/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3769 - accuracy: 0.1950
# Epoch 21/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3659 - accuracy: 0.2170
# Epoch 22/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.2170
# Epoch 23/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3474 - accuracy: 0.2170
# Epoch 24/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.2170
# Epoch 25/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3325 - accuracy: 0.2170
# Epoch 26/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.3259 - accuracy: 0.2180
# Epoch 27/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.2360
# Epoch 28/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3144 - accuracy: 0.2570
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3091 - accuracy: 0.2590
# Epoch 30/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3042 - accuracy: 0.2600
# Epoch 31/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2991 - accuracy: 0.2700
# Epoch 32/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2943 - accuracy: 0.2730
# Epoch 33/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2894 - accuracy: 0.2700
# Epoch 34/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2849 - accuracy: 0.2730
# Epoch 35/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2802 - accuracy: 0.2780
# Epoch 36/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2754 - accuracy: 0.2750
# Epoch 37/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2709 - accuracy: 0.2730
# Epoch 38/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2663 - accuracy: 0.2570
# Epoch 39/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2615 - accuracy: 0.2470
# Epoch 40/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2568 - accuracy: 0.2470
# Epoch 41/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2522 - accuracy: 0.2490
# Epoch 42/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2476 - accuracy: 0.2600
# Epoch 43/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2429 - accuracy: 0.2490
# Epoch 44/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2384 - accuracy: 0.2470
# Epoch 45/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2340 - accuracy: 0.2720
# Epoch 46/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2294 - accuracy: 0.2590
# Epoch 47/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2248 - accuracy: 0.2760
# Epoch 48/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2206 - accuracy: 0.2750
# Epoch 49/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2163 - accuracy: 0.2610
# Epoch 50/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2117 - accuracy: 0.2700
# Epoch 51/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2075 - accuracy: 0.2760
# Epoch 52/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2030 - accuracy: 0.2760
# Epoch 53/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1987 - accuracy: 0.2760
# Epoch 54/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1946 - accuracy: 0.2760
# Epoch 55/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1905 - accuracy: 0.2760
# Epoch 56/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1865 - accuracy: 0.2760
# Epoch 57/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1825 - accuracy: 0.2760
# Epoch 58/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1786 - accuracy: 0.2760
# Epoch 59/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.2760
# Epoch 60/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1712 - accuracy: 0.2760
# Epoch 61/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1675 - accuracy: 0.2760
# Epoch 62/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1641 - accuracy: 0.2690
# Epoch 63/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1604 - accuracy: 0.2730
# Epoch 64/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1570 - accuracy: 0.2470
# Epoch 65/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1536 - accuracy: 0.2440
# Epoch 66/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1500 - accuracy: 0.2440
# Epoch 67/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1467 - accuracy: 0.2440
# Epoch 68/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1435 - accuracy: 0.2440
# Epoch 69/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1403 - accuracy: 0.2440
# Epoch 70/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1372 - accuracy: 0.2440
# Epoch 71/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1340 - accuracy: 0.2440
# Epoch 72/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1309 - accuracy: 0.2440
# Epoch 73/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1279 - accuracy: 0.2440
# Epoch 74/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1250 - accuracy: 0.2440
# Epoch 75/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1222 - accuracy: 0.2440
# Epoch 76/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1194 - accuracy: 0.2440
# Epoch 77/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1167 - accuracy: 0.2440
# Epoch 78/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1142 - accuracy: 0.2440
# Epoch 79/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1115 - accuracy: 0.2440
# Epoch 80/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1089 - accuracy: 0.2440
# Epoch 81/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1065 - accuracy: 0.2440
# Epoch 82/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.1040 - accuracy: 0.2440
# Epoch 83/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.2440
# Epoch 84/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0993 - accuracy: 0.2440
# Epoch 85/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.2440
# Epoch 86/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.2440
# Epoch 87/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.2440
# Epoch 88/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0903 - accuracy: 0.2440
# Epoch 89/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0882 - accuracy: 0.2440
# Epoch 90/100
# 32/32 [==============================] - 0s 3ms/step - loss: 0.0861 - accuracy: 0.2440
# Epoch 91/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0841 - accuracy: 0.2440
# Epoch 92/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0821 - accuracy: 0.2440
# Epoch 93/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0802 - accuracy: 0.2450
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0783 - accuracy: 0.2490
# Epoch 95/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.2450
# Epoch 96/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0748 - accuracy: 0.2500
# Epoch 97/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0731 - accuracy: 0.2440
# Epoch 98/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0715 - accuracy: 0.2500
# Epoch 99/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0699 - accuracy: 0.2570
# Epoch 100/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0683 - accuracy: 0.2510
# 1/1 [==============================] - 0s 73ms/step
# Input Binary Vector (5 bits): [0. 1. 1. 1. 0.]
# Input in Decimal: 14
# Predicted Squared Binary Vector (10 bits): [0 0 1 1 0 0 0 1 0 0]
# Predicted Output in Decimal: 196
